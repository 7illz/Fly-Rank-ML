# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/7illz/Fly-Rank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Chosen Lane: Lane 2 - Refresh / Content Opportunity Scoring
#
# Why this one: This lane connects a predictive model directly to a human workflow. Instead of just outputting an abstract accuracy metric, the model's output becomes a ranked queue. By prioritizing pages that need attention, this project optimizes the limited daily capacity of a content review team, proving the immediate business ROI of an algorithmic approach.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *The Decision: Which specific web pages should the content team prioritize for manual review today?
#
# The Action: A human reviewer opens the top-ranked pages in the queue to decide if they require a title rewrite, content expansion, or metadata fix to recover lost visibility.
#
# Cost of a wrong call: A false positive (ranking a healthy page highly) means a human reviewer wastes 15-30 minutes investigating a non-issue. A false negative (missing a declining page) is much worse; a high-traffic page silently decays, resulting in a prolonged loss of organic traffic and engagement.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os

# Resolve path to the small anonymized starter slice
# Adjust the relative path if your notebook is deeper in the directory structure
data_path = '../../data/raw/content_refresh_anonymized.csv'

if os.path.exists(data_path):
    df = pd.read_csv(data_path)

    # 1. Total volume of the starter slice
    total_rows = len(df)

    # 2. Check the baseline distribution (pages marked as declining)
    declining_pages = len(df[df['trend_direction'] == 'down'])
    decline_ratio = (declining_pages / total_rows) * 100

    print(f"--- STARTER DATASET AUDIT ---")
    print(f"Dataset volume: {total_rows:,} rows.")
    print(f"Pages showing decline: {declining_pages:,} ({decline_ratio:.1f}% of the dataset).")
    print("Target to beat: The current baseline rule set only achieves a Precision@50 of 0.240.")
else:
    print(f"Error: Could not locate the raw starter data at {data_path}. Please verify your repository structure.")
# Out:
# Error: Could not locate the raw starter data at ../../data/raw/content_refresh_anonymized.csv. Please verify your repository structure.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *What I can claim (Observed & Decision-Support): I can identify and rank pages that have a high statistical probability of declining based on historical search, volume, and engagement signals. This acts as a decision-support tool to focus human effort.
#
# What I cannot claim (No Causal Proof): I cannot claim that updating the content will guarantee a traffic recovery. This relies on observational data, not a controlled causal experiment (like an A/B test). Furthermore, this model does not reverse-engineer or "predict" Google's specific ranking algorithm factors.*

# %%
# No code required here; careful words documented in the Markdown cell above.
pass

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
